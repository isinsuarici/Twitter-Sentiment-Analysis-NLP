# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
import re
import string
import nltk
from nltk.corpus import stopwords
import gensim
import pyLDAvis.gensim_models
from gensim.models import CoherenceModel
from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
import time
 #pip install wordcloud
from wordcloud import WordCloud
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
import pickle
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing dataset

# %%
columns  = ["sentiment", "id", "date", "flag", "user", "text"]
df = pd.read_csv('dataset.csv',names=columns)

# %%
df.head()
# Out:
#    sentiment          id                          date      flag  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
df.tail()
# Out:
#          sentiment          id                          date      flag  \
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...

# %%
df = df[['sentiment','text']]

# %%
#4 in the sentiment column for positive tweets and 0 for negatives in the data set.
#Let's change 4 to 1 and make the sentiment category of positive tweets "1".

# %%
df['sentiment'] = df['sentiment'].replace(4,1)

# %%
df.tail()
# Out:
#          sentiment                                               text
# 1599995          1  Just woke up. Having no school is the best fee...
# 1599996          1  TheWDB.com - Very cool to hear old Walt interv...
# 1599997          1  Are you ready for your MoJo Makeover? Ask me f...
# 1599998          1  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999          1  happy #charitytuesday @theNSPCC @SparksCharity...

# %%
df['sentiment'].value_counts()
# Out:
# 0    800000
# 1    800000
# Name: sentiment, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   sentiment  1600000 non-null  int64
#  1   text       1600000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 24.4+ MB

# %%
text, sentiment = list(df['text']), list(df['sentiment'])

# %% [markdown]
# # Text Preprocessing

# %%
def clean_dataset(textdata):
    processedText=[]
    wordLemm = WordNetLemmatizer()
    urlPattern        = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
    userPattern       = '@[^\s]+'
    alphaPattern      = "[^a-z0-9#]"
    stopwords_set = stopwords.words('english')
    
    for tweet in textdata:
        tweet = tweet.lower()
        tweet = re.sub(urlPattern,' URL',tweet)
        tweet = re.sub(userPattern,' USER', tweet)   
        tweet = re.sub(alphaPattern, " ", tweet)
        tweet = " ".join([i for i in tweet.split() if i not in stopwords_set])
  
   
        tweetwords = ''
        for word in tweet.split():
            if len(word)>1:
                word = wordLemm.lemmatize(word)
                tweetwords += (word+' ')
        processedText.append(tweetwords)
    
    
    return processedText

# %%
t = time.time()
processedtext = clean_dataset(text)
print(f'Time Taken: {round(time.time()-t)} seconds')
# Out:
# Time Taken: 216 seconds

# %%
processedtext
# Out:
# ['awww bummer shoulda got david carr third day ',
#  'upset update facebook texting might cry result school today also blah ',
#  'dived many time ball managed save 50 rest go bound ',
#  'whole body feel itchy like fire ',
#  'behaving mad see ',
#  'whole crew ',
#  'need hug ',
#  'hey long time see yes rain bit bit lol fine thanks ',
#  'damn chalk chalkboard useless ',
#  'blast getty villa hate sore throat day getting worse ',
#  'hey missed ya meeting sup mama ',
#  'tummy hurt wonder hypnosis anything working get stop smoking ',
#  'always fat one ',
#  'sorry babe fam annoys thankfully asleep right muahaha evil laugh ',
#  'paid attention covered photoshop webpage design class undergrad ',
#  'wednesday day know ',
#  'poor cameron hill ',
#  'pray please ex threatening start sh baby 1st birthday party jerk still headache ',
#  'hmm really enjoy problem constant think thing find someone ulike ',
#  'strider sick little puppy ',
#  'rylee grace wana go steve party sadly since easter wnt able much ohh well ',
#  'hey actually one bracket pool bad one money ',
#  'follow either work ',
#  'bad nite favorite team astros spartan lose nite good ',
#  'body missing northern calif girl found police found remains missing northern california girl ',
#  'hope increase capacity fast yesterday pain got fail whale 15 time hour ',
#  'behind class work ',
#  'watching quot house quot ',
#  'remember bum leg strike back time serious ',
#  'cool kind complaint laptop online overheating recall ',
#  'emily glad mommy done training new job miss ',
#  'would rather first party send bad message 3rd party send mixed one sophmore year ',
#  'overrated ',
#  'know heard afternoon wondered thing moscow behind time ',
#  'laying bed voice ',
#  'sooo sad killed kutner house whyyyyyyyy ',
#  'sorry tell mea culpa really sorry ',
#  'make sense suicide thing refuse believe actually happened ',
#  'hope ok ',
#  'damn grind inspirational saddening time want stop cuz like much love ',
#  'yeah aw know wudnt stand chance ',
#  'ugh cant sleep 30am ',
#  'hanging crooner wanna sing suck ',
#  'aaw miss ya im leaving bh tomorrow quot morning quot think aww wanna go beach girl ',
#  'pissed asba radio station ',
#  'wednesday day know ',
#  'know life flipped upside thought head ramen sound good ',
#  'pain back side hurt mention cry made fail ',
#  'late night snack glass oj quot sickness quot back sleep ugh hate getting sick ',
#  'big fan camilla belle ',
#  'wah see clip must el stupido work filter wait till get puter something else blame ex broke mine ',
#  'week seems get longer longer term much need much actually going get done ',
#  'cold ',
#  'ehhh weather gonna take turn ugly tomorrow ',
#  'haha cooooold still go show incredible stuff ',
#  'hoping tummy rumble go away soon ',
#  'notice told working tomorrow called agency follow said ',
#  'almost bedtime ',
#  'missing babe long alive happy yawwwnn tired love imma try sleep hopefully headstart ',
#  'agh snow ',
#  'miss kenny power ',
#  'thank letting people know sad direct message got actually bridget ',
#  'india missed 100th test victory 10th consecutive win without loss ',
#  'guess ',
#  'sadly going bed ',
#  'shame hear stephan ',
#  'hey leavin morning ',
#  'intending finish editing 536 page novel manuscript tonight probably happen 12 page left ',
#  'laid around much today head hurt ',
#  'still read 9th amp 10th princess diary saving francesca made cry end hmm easy book ',
#  'nokia 1110 died ',
#  'mom might breast cancer find anything like week worried ',
#  'going sleep hoping tomorrow better day ',
#  'lol wish understood daylight saving ended though breakfast hour later keep waking kid ',
#  'lame ',
#  'understand really ',
#  'hero season ',
#  'living downtown sure much fun ',
#  'calorie wise wish junk food calorie free ate thing sour skittle big as cherry coke ',
#  'man work hard ',
#  'getting sick time hot tea studying sleeeep ',
#  'getting eyebrow waxed pain ',
#  'phantasy star yesterday going work ',
#  'oh got macheist apps sweet get espresso serial though although said sent oh well ',
#  'picked mich st win get go feeling pretty good pick way tonight lost ',
#  'alone downstairs working ',
#  'feel bad ',
#  'hate anoop mean seriously kinda mean ',
#  'yes sprint 4g baltimore chicago far ',
#  'stuck awake middle night second day row felt terrible yesterday ',
#  'thanks bursting bubble ',
#  'going school soon find anything wear gosh hard ',
#  'serious lol ',
#  'page sooooo long got deleted sad day history ',
#  'crazy wind today birding ',
#  'currently work ',
#  'grrr ipod acting weird jai ho thinking playing full song ughh ',
#  'send dvd co missed heap happy ',
#  'see big deal website ',
#  'sorry go #therapyfail ',
#  'far way rail tip ',
#  'still swear keep losing gaining losing gaining tweeps heart wrenching ',
#  'today realized good hiding thing even find ',
#  'staying friend house house sitting neighbor loud party ',
#  'danny im upset wasnt watch live chat car hour trip im soooo upset ',
#  'check mug ',
#  'border closed 10 ',
#  'downloading nin new album quot slip quot hell come behind time day ',
#  'woke already written mail go early university today teach 30 ',
#  'watching hill making sad ',
#  'many channel yet boring lazy day may find hobby ',
#  'miss buddy ill ny 25th ',
#  'love french tell people south qtr french snarl french beautiful people ',
#  'opps said still got one day remain problem come ',
#  'activated selfcontrol block early meaning check new qc regularizing internal clock might difficult #fb ',
#  'oh ',
#  'spencer good guy ',
#  'reese dying #ttsc season finale next week #24 boring madame president crazy woman ',
#  'hate limited letter hope guy fine pray dog well ',
#  'get shit done today screwed ',
#  'wanttss go ',
#  'going sleep tonite ',
#  'worried tired post tonight ',
#  'get shit done today screwed ',
#  'job interview cardiff today wish luck got hour sleep ',
#  'show whack way worse whack wiggety whack ',
#  'really think people choose way think chose accept family help might dead ',
#  'going kill seen ds9 waiting till one solid week sitting ',
#  'think ur right hahaha hr ',
#  'hate see spartan sad ',
#  'mind body severely protesting quot getting quot thing nightmare boot ',
#  'goin follow since lol go angel ',
#  '',
#  'think want read book library ',
#  'nap interrupted many time today going japanese rent ',
#  'kind longs bus show end ghost world right ugh ',
#  'canada canada weird supposed get snow wednesday ugh ',
#  'awwh babs look sad underneith shop entrance quot yesterday musik quot like look new transformer movie ',
#  'sad foot macbook fell ',
#  'gonna get late tomorrow 132am gonna get tipsy lonesome sad ',
#  'sweating forthcoming trip e3 find someone crash may screwed ',
#  'gotten somebody read tweet cant get make account ',
#  'omgawd couldnt handle cat heat time ',
#  'hope make auburn show looking good ',
#  'thats people mag haha couldnt fit dont think picture ever made magazine tho haha ',
#  'congrats totally forgot submit photo ',
#  'awww good luck paula please work hard hope fun new album gonna amazing xxx ',
#  'leaving get sad ',
#  'miss twitter phone broke using stupid nokia phone ughhh miss advance phone ',
#  'shooting outside house kidding scared ',
#  'tuesday start reflection lecture stress reducing technique sure might become useful u accompaniers ',
#  'tragedy disaster news week ',
#  'yes yes still trying find picture upload correclty ',
#  'oh red sox game rained looking forward opening day ',
#  'still find key ',
#  'know right dunno going twitter ',
#  'might getting sore throat ',
#  'home town mammy called depressd pls explain parent let 8yr old child walk alone hello 2009 ',
#  'think need find better anti depressant think paxil wellbutrin combo losing efficacy ',
#  'help need new boyfriend stuck rut ',
#  'feel like complete idiot one get shit work help ',
#  'saw ad craigslist casting call female host g4 totally psyched realized hoax ',
#  'pepperoni roll called valentino said sausage roll pepperoni roll ',
#  'yes monday ',
#  'want new gg episode already ',
#  'miss watching rocko modern life ',
#  'rip sandra sad someone something like ',
#  'keeping finger crossed buddy feeling well ',
#  'wait eat skinny vega hungry ',
#  'tried tweetdeck hated passion hated sure ',
#  'btw iphone acting funny dying quickly freezing b admitting anything sayin ',
#  'sitting wondering quot ed quot still strong hold ',
#  'im sorry got sick lol going bed night ',
#  'internet home drive ox use internet builder ',
#  'weather canada freezing ',
#  'twiggassssssss range day back hopefully good ',
#  '',
#  'anyone read pray grandma pain ',
#  '#3 woke accident quot pushing pushing quot cry stop wetting pant ',
#  'home franklin street almost jumped fire someone kicked could jenny lost shoe ',
#  'hey changed default ',
#  'finally gave bored enough start thing think 140 going problem tho like myspace status ',
#  'oooonly really lucky eh awh definitely early work ',
#  'buttload homework ',
#  'need another copy visual studio 2008 ',
#  'school world week school silly anyway look bright side ',
#  'omg economics test dont know thing know omg im gonna fail ',
#  'upon time hundred island pride philippine tourism coral clam rare fish poaching kinda sad ',
#  'yeah apparently really bad taste ',
#  'know really surprised since everyone recommends youtube call tomorrow figure ',
#  'waiting airport ride get harassed men trying sell ugly hat want sleep ',
#  'left id location go bar fuckkkkkkkkkkkkk ',
#  'sorry understand last comment ',
#  'announcement stayed late last night ',
#  'strange illegal torrent avlbl everywhere legal dvd stock ',
#  'enough say imiss ',
#  'trolley packed like sardine padre game remove car good call mt ',
#  'jeez trying help haha ',
#  'happened saturday night along glittery green lighter ',
#  'trying reduce number cigarette day ',
#  'yea quiet around cuz everyone work im bored death nobody talk ',
#  'gotta cooking assignment hard ',
#  'okay applepears talked people one ever told never ',
#  'know night owl nature hahaha time zone behind almost ',
#  'lol nope complete #camerafail ',
#  'useless sleep fair want fun well ',
#  'pookie uti nurse gabbie get back 100 soda ',
#  'tweet something damn hang please ',
#  '',
#  'behind video game everything matter yesterday news ',
#  'one left got tempted ate soon got home chocolate velvet amp ate mocha ',
#  'stressing blackberry keep flashing red alert status reason faking hate ',
#  'wanna wear doc marten worn since december ',
#  'shoe repair shop guy could find shoe go back see find couple day ',
#  'really see coming ',
#  'woke vivid sketchy cool dream life time stare wall light ',
#  'take day sister get passport ',
#  'oh yes miss ',
#  'uh oh think getting sick ',
#  'good god ruined belly button ',
#  'watching framed roger rabbit make miss toon town ',
#  'renting cheap renting awesome house buying attempt fall ',
#  'running nose spinning head good combination meeting ',
#  'negative lost vote confidence ',
#  'nasty budget due iphone sent apple today ',
#  'bad ',
#  'dammit episode king play reason stopped middle anything ',
#  'upset missed chat quiz online free internet ceased ',
#  'believe disbelief way really much take people always get hurt others ',
#  'car show season started without ',
#  'throat raw ',
#  'get person mind could even ish like prayer fam real ',
#  'hate need see need call therapist ',
#  'twilight come yesterday finger crossed today ',
#  'glad able help feel better hate see sick love ',
#  'tireddddddd want sleep assignment finish exam tomorrow study ',
#  'know thinking need money ',
#  'omg jst teusday ',
#  'ummmmm cant find ',
#  'heard found sandra cantu yr old ',
#  'ive forgotten snoo snoo wonder snoo snoo ever meet ',
#  'wow last tweet made seem like giant sexist sorry ',
#  'bathtub drain fired haz job amp iz fail got drano as amp iz still draining wanna shower dangit ',
#  'stuck home ',
#  'mine 10 get ',
#  'duckling famous child book stolen boston public garden boston globe via oh ',
#  'thank however hate list includes convict ',
#  'heading altrincham hour install ',
#  'morning good im bloody knackered work today helppp xxx ',
#  'garage park driveway ',
#  'happened ',
#  'quot popular music quot adorno probably difficult reading ever prescribed actually struggling continue ',
#  'cant see flower falling dont camera cellphone ',
#  'good liking snow right getting used nice spring like weather ',
#  'pity youtube currently blocked china see vids ',
#  'happened show hightlight life ',
#  'best leather sofa world office though mean still working ',
#  'still day internet get uncapped ',
#  'get better day could something lodged belly ',
#  'love atekinzz much amp amp soo miss ',
#  'wanna sneak zoo play kitty ',
#  'oh hope getting sick ',
#  'dont think cause cousin birthday party ',
#  'sweet little man fell asleep waiting daddy big brother get home poor baby missed much today ',
#  'angel going miss athlete weekend ',
#  'trust hard ',
#  'watched considering today yaknow shawnna tomomorrow need bestfriend ',
#  'grr want keep reading wont anything left read ',
#  'atekinzz world ',
#  'supposed date ',
#  'pear amp brie bottle cabernet quot win date tad hamilton quot oh gawwd life flashed forward 40 75 cat ',
#  'crap need dress ',
#  'yeah know horrible ugh saddening ',
#  'geez ur fun ',
#  'wanna punk rock band ',
#  'lot angst tuesday afternoon ',
#  'glad britney crazy anymore one hell show sad next ap cook county ',
#  'huuuge headache omg feel like crap ',
#  'sorry ',
#  'sorry rooting ',
#  'man took forever ',
#  'see ',
#  'listing item ebay sell take forever meanwhile coleman watching hill season premier without ',
#  'got presentation done 23 slide done cry week hardest week ',
#  'lost 160 ',
#  'like previously skin thing start season two like went straight intro like ',
#  'wish pretty good scaring shit people ',
#  'going sound vain running fav lip gloss ',
#  'never click link scream quot spider spider quot known better yucky ',
#  'time work get sick ',
#  'imac came 320 indonesia state ',
#  'dammit need stop buying furniture ',
#  'half asleep turned laptop ',
#  'death peaceful life however bite ',
#  'think lost net sure hope ',
#  'test footage girlfriend hd dark one underxposed ',
#  'tough game watch tonight state finally going bed also staying watch season premiere hill ',
#  'seems jruby support hpricot two version behind ',
#  'unlike sister still one ',
#  'fraking app store pissing ',
#  'logging need study ',
#  'anyone else problem accessing ttb cant get ',
#  'strongly dislike people make stupid comment dont know whole story ',
#  'sorry emma swarley goldfish sad ',
#  'tweet already gone missed guy tonight ',
#  'sleep face kinda swollen let allergic thing get thursday school tomorrow doubtful ',
#  'izzy cat tree stare floor chase run ',
#  'officially banning godaddy com comp head hurt small print wasted 10 could happily gone boba ',
#  'pretty much scary ',
#  'mine finding well hard get fit ',
#  'good morning ready go want go back bed ',
#  'hate waiting mail ',
#  'wheat bread dollar store toast nicely going tax calling early night ',
#  'kutner mean knew something going happen someone sad lt house well done still sad ',
#  'aw ok goonite ',
#  'ill cant go cinema ',
#  'ugh disconcerting ',
#  'actually whole site finally taken damn russian ',
#  'tweet arent going ',
#  'finished delicious breakfast last paris miss milk europe tastiest milk world drink u ',
#  'ilearn great considering final week ',
#  'stressed outttt ',
#  'also shouldve bern asleep hour ago ',
#  'trying figure twitter thing none friend yet soo much see ',
#  'pinging custom icon made look cool edge could le square might look bad diff background ',
#  'want back la ',
#  'dunno use forum get frustrated miss talking ',
#  'option ',
#  'unfortunately one moment giant squid monster ',
#  'want one branch midv open ',
#  'aw sorry hear ',
#  'change plan ordered mac instead time hit book ',
#  'yup ',
#  'see donnie tweet stats almost 700 reply jrk ',
#  'nah received stimulus yet ',
#  'seen ur tweet plz write bak get havnt got one reply bak ',
#  'awwwww trying go sleep hour ago ',
#  'sorry hear always sad lose close u loved ',
#  'cant sleep im still feelin like piece shit ',
#  'oh sympathy hard decision always hope old border collie go sleep 14 hug ',
#  'well really cool part wont spoil ',
#  'time warp without sad ',
#  'true lol still slap face warm end march ',
#  'hate converting movie put em itouch ',
#  'gross pimple ',
#  'yea naaaaaaaaaaaaaaaaaaaam marwan accent lol ',
#  'one le follower tonight ',
#  'mom last night brb figure whether burned ',
#  'feel like quot twitterer quot tweetdeck ',
#  'karate tournament week ',
#  'going sleep 1am finish statistic homework ',
#  'north carolina baby aint nothin stopping nba draft ',
#  'sleep ',
#  'reaaly miss john mayer twitter fuck rude people remove like tweet bitchfucks ',
#  'going late one mqu today ',
#  'im tired work need life ',
#  'leavin work foot hurt ',
#  'sad unexpected totally cried haha ',
#  'superneej morning bah car start waiting anwb ',
#  'still homework ',
#  'little sad ',
#  'mom amp dad get around early ',
#  'asleep two hour ago ',
#  'sorry hear dog ',
#  'funny little thing make homesick criminal breakn n2 brownstone lawnord ci made misty ',
#  'yeah great vid 12 quot single sold year ago ',
#  'im val mac iitsc clubroom still sweating ',
#  'awww sad sorry ',
#  'updatingffe give nothing good twenty minute ',
#  'hot compress rily workng pulled muscle gng bed good night ',
#  'invite quot healthy dining quot session ashok hotel today exec chef chopra damn workload skip ',
#  'sorry hear dog wishing happier day come ',
#  'miss em ',
#  'cool tweet apps razr ',
#  'bed gotta wake hella early tomorrow morning ',
#  'still procrastinating hate organizing clothes much ',
#  'playing new mobbler v0 add great new feature play music e71 like v0 ',
#  'oh one bestie missing ',
#  'time come back flawda double date seriously sorry hear ',
#  'way late working client 12 10 #fb ',
#  'blegghhhh go work ',
#  'back work john muir dr ',
#  'emailed yesterday never responded ',
#  'going long year fan ',
#  'got done watching new house episode definitely one saddest episode ever ',
#  'man tax suck horrified something wrong turbotax decided keep around lot stuff turned ',
#  'sleep time tomorrow gonna suck ',
#  'wtf kutner oh pissed house mean really wtf ',
#  'know dont know said ',
#  'cash rule everything around ',
#  'picked oat market eat breakfast boy time work usc late night ',
#  'feel sick much icecream ',
#  'computer shockwave blah account yet ',
#  'awww wish could go sydney ',
#  'hahaha suriously feel like everyone know show joke except lc ',
#  'spell today totally suck ',
#  'vaccinated chicken pox vaccinate yr old confused damn thing ',
#  'school least last day ',
#  'yawwwn gotta get early tomorrow ready weekend ',
#  'miss home calving season sad black one died morning wish bottle calf ',
#  'sorry loss brother dog sam sick cushing disease ',
#  'back work get spend next hour alone dispatch room ',
#  'new kind starburst favereds sound fab bc cherry strawberry fav red added watermellon yucky ',
#  'well much productive day angel ',
#  'oh gee insomnia suck tried melatonin ',
#  'good hear support netbeans netbeans know ',
#  'wish would get time rest world unfornately cairo wait mtva play ',
#  'heartbroken little sandra prayer family ',
#  '900 word finish tomorrow maybe ',
#  'come ur background cover screen mine corner ',
#  'wrote exactly three line dialogue tonight gave ',
#  'complaint facebook changed much confusing ',
#  'sliced finger ',
#  'going thru town traffic bypass stink ',
#  'ugh sleep wish good cuddle make as ',
#  'hate software update downloads update without telling never know downloading ',
#  'went ihop great diet least kung foo pancake time rachel ',
#  'internet hating night pose ',
#  'jealous missed opening day year ',
#  'cruel wait review come far look like star trek best film year ',
#  'debating shower sleep little later tomorrow ',
#  'stress always culminates physical pain ',
#  'need sleep cant ',
#  'little pinky finger hurt much ',
#  'sorry gift card ran suck ',
#  'home spring break one home tho ',
#  'accessed oneindia mobi google phone android support indic language ',
#  'school take life much get sleep anymore still school work well ',
#  'aw wish could really speak yia yia speak english ',
#  'free comp lol ',
#  'getting ready clean house top bottom ',
#  'cry friend moving away tomorrow ',
#  'stop nomnoms share night people ',
#  'think getting cold caught daddy oh trip would ruined ',
#  'yeah bcoz kal penn visiting lecturer somewhere cant show anymore im gonna miss ',
#  'procrastination start early quarter want reaaaaad write paper ',
#  'apparently 52 degress 11pm washington state miss winter already ',
#  'bored homee ',
#  'massage great spilled coke desk lame watching simpson finished hill dvd ',
#  'wait fanclub chat even tough favorite ',
#  'mild left inner ear infection got irritating quot blocked quot feeling since sunday ',
#  'hey nope cuteness away awhile ',
#  'tuesday ',
#  'haha even yo know twitter haha ',
#  'someone alarm clock phone woke 3am still got headache yesterday night ',
#  'awww poor puppy ok ',
#  'might break eat buffalo wing tomorrow ',
#  'sittin kayla really really reallly dis like brother know stop waiting day one ',
#  'fed bokkie many birthday treat sicko ',
#  'kinda bummed agency told look going lady please help create look ',
#  'work laptop officially dead happy ',
#  'goodness freezing ',
#  'put listen mom ',
#  'stucked paris even travel france work ',
#  'think one close last time checked closest one 70 mile away ',
#  'aaaaand back literature review least friendly cup coffee keep company ',
#  'worried get 900 even though paid buttload tax last year ',
#  'okay still school ',
#  'phoneless sleep ',
#  'reeked alcohol dentist morning drunk put tshirt realised huge stain dentist looked disgusted ',
#  'really cold ',
#  'cant sleep want dream ',
#  'sleep hate night try go bed early stay awake hour poo ',
#  'yeah bad people like certain burrito eating man exist ',
#  'sad ',
#  'found mum adopted auntie twitter check mum tessm64 awesome auntie tania38 ',
#  'cannot sleep wide awake gotta go work later boy going crappy day ',
#  'struggling eam law ',
#  'sleep like ',
#  'bout start 24 poor linny keep eye open tired work tomorrow morning night ',
#  'year old 18 year old driving around twist want like ',
#  'well sucked ',
#  'place day help get packing painting cleaning much appreciated oh rip wall ',
#  'opening partially frozen beer beer toaster oven counter kitchen smell like run speakeasy ',
#  'dont even know ride ',
#  'sadly yes think need counciling ',
#  'making ready school feel like going two test ',
#  'smugness gone train also failed turn heading victoria followed unpleasant tube ride city ',
#  'anybody know ipod went ',
#  'aww earthquake italy made sad saw pic news terrible ',
#  'never able afford get much rather go extraction continue deal ',
#  'pet care people try run others business send suspicious mail fishing info ',
#  'lt 33 codez mia tho ',
#  'doesnt work cell go sleep ',
#  'going nice tomorrow rain come back nice weather birthday ',
#  'rock band hard expert ',
#  'roomie home day scratch door comforter goto large laundromat machine ',
#  'one hardest thing schedule one chat end day usually ',
#  'killed character one favorite show upset ',
#  'jealous friend got see new star trek film austin tonight ',
#  'listening got really bad headache drivin lesson ten min lucky wana sleeep ',
#  'shut hungry britain home boring suckassy breakfast world miss dennys ',
#  'good morning everybody pkoi fais pa beau bon coffee time ',
#  'work ',
#  'essay time ',
#  'hey talk mom home yet hope ok wish coming home easter ',
#  'sure wish could go guy tmrw per usual school interferes ',
#  'say kal penn leaving house noooooo awww totally missed tonight ',
#  'lost loyal ',
#  'played another hand bad lost half stack ',
#  '20pm early day looooooong night work ',
#  'sad last season wanna see spencer call lauren ',
#  'im done editing quot phipstape quot back crack brew see got tree though ',
#  'know half mean ',
#  'homework homework homework ',
#  'worked heart today doubling weight station result stiff pulled muscle ouch ',
#  'feel bad unfollowing ',
#  'tired god hate new job two day ',
#  'sad kutner killed fav show house ',
#  'happy coach stringer hof 2009 finish term paper ',
#  'feel like shit way want spend birthday eve ',
#  'far 311 site put together checking update made ',
#  'lot mind need make money idea nowhere hiring ',
#  'miss ',
#  'sorry hear dog ',
#  'much internet plague ',
#  'miss ex soo much ',
#  'sodding m25 ',
#  'oh thought pirate bay trial verdict today apparently 10 day ',
#  'call back ',
#  'study hall log immediately ',
#  'tired im cry reason im try get hour half tonight half got last night ',
#  'totally like four girl option none seem viable ',
#  'far 311 veiws site put together checking update made ',
#  'listening bjork full love cry ',
#  'omg hill love money2 aww think becky buckwild go ',
#  'craving tantan nabe ',
#  'mon sean man ',
#  'watching quot league quot make miss mint chocolate ice cream cone grand fuck ',
#  'lost phone maybe grass long hope rain ',
#  'hope referring say hello new stalker lol ',
#  'sleeping ur gonna night ur bike ride ',
#  'wanna listen master ',
#  'looking good stuff write also load uni work ',
#  'feel unloved dropped tweeter ',
#  'london day thursday gonna raining oh fab see much london eye still robbie care bless ',
#  'completely wiped reloaded 8900 lost bbm contact going bed sad ',
#  'sayyyy whaaaa invited ',
#  'sleep bad considering workshop starting today beginning sore throat though ',
#  'oh gosh made emotional haha idk dont want get old ',
#  'going post story manually due twitterfeed problem quiet lately ',
#  'like lukewarm shower ',
#  'contact need 1099 freelance work linux com throughout 2008 never got one ',
#  'connor febi really really mad ',
#  'need help want buy macbook pro still inlove old powerbook ',
#  'man america borez anyway lol realized sent msg idea flash ',
#  'knight lovely lady sleepy ',
#  'anybody know get electrolyte back order vitamin work feel sick ',
#  'yes someone reading post properly ',
#  'almost italian homework weeeeee understood ',
#  'turned light time get ip ',
#  'twitter hate u ',
#  'hate fact genuinely excited last tweet ',
#  'sleep either ',
#  'italy earthquake sad news day ',
#  'rain today garden really need quite bad ',
#  'yawn yawn yawn 10 minute bed ',
#  'ouch sound sucky ',
#  'great idea itunes promo code work uk itunes store though ',
#  'cry ',
#  'empty rum barrel sad rum barrel shake head horror horror ',
#  'sleepless night ',
#  'admitted fake ',
#  'love chutney ',
#  'got highly bored today scanning 24 page daddy ',
#  'cooked risotto without ',
#  'keeeerrrrriiiiii really nothing better post thing 224am wonderfullll say alot ',
#  'yay baseball season boo yankee losing first game ',
#  'lost suck work today ',
#  'omg exam killed could know difference haif circle hemisphere lt gt ',
#  'bed suddenly feel wish goodnight twitterfam ',
#  'like goodnights ',
#  'greaaat lappy turn wtffffff ',
#  'stuck traffic journey traffic free morning help ',
#  'lookin like nighter hate ',
#  'stranger ',
#  'debbugging old vb6 code day could started better ',
#  'quarter percent babe darn ',
#  'coming cold bad allergy either way miserable ',
#  'believe cutner dead house sad day santa rosa ca ',
#  'damnit really digging season reaper ',
#  'gah comcast doubled cable internet bill telling u quitting anyone suggest affordable company bay area ',
#  'another early morn duchess although managed cross leg time ',
#  'left without saying hi ',
#  'want sleep ',
#  'xbox show three red light mean dead need fixed month microsoft hq ',
#  'king sized bed nice sad lonely hubby puppy kitty whole conferenceing thing ',
#  'im boredd gah wish could sleep get ive toooo muchh cooooffffeeeeeeeee bahaha ',
#  'may butt done nosey sorry conversation interesting ',
#  'fell list offend ',
#  '18 week till sister home missed call worst feeling world ',
#  'gonna try get sleep hotel room ',
#  'brilliant idea bring much think spend amp swap bring brolly ',
#  'get autograph shout record though computer dead listen ',
#  'rt khloe got fired apprentice ',
#  'biology class lip hurt ',
#  'sorry next tweet ',
#  'grr go school today ',
#  'get hd tivo got set tonight order get channel 40 59 ',
#  'asked everyone yesterday single tweet back ',
#  'ruddy money like still waiting oh surprise state hmmm seriously ',
#  'sad kutner favorite new team ',
#  'wow get quot hello quot suck ',
#  'bedtime school tomorrow still book broke suck ',
#  'seating helping baby paper well forcing seat im sleepy ',
#  'synching contact old mobile iphone import work well ',
#  'concentrate ',
#  'spent hour enter bureaucratic nonsense march waste time ',
#  'nw confused ever ',
#  'feeling well stupid migraine making tummy upset whole body ache shoot ',
#  'reading buyology bedtime great premise turning quot ok quot book lot info already knew ',
#  'home really wana sleep due wasting free line town assignment finish ',
#  'also send update plurk upload photo twitter didnt see update plurk zero ',
#  'omg quot reader quot making ',
#  'oh least getting decent exchange rate moment sterling still getting flogged ',
#  'tried download tweetdeck wont download ',
#  'inch snow ground counting worried poor flower ',
#  'happy camper ',
#  'thanks man grateful feel unworthy attention though ',
#  'miss totally comin back tho lastnight sooooooo much fun ',
#  'ohhh love p sad get hang ',
#  'somehow still end place ',
#  'oh sad poor boy ',
#  ...]

# %%
processedtext[1:5]
# Out:
# ['upset update facebook texting might cry result school today also blah ',
#  'dived many time ball managed save 50 rest go bound ',
#  'whole body feel itchy like fire ',
#  'behaving mad see ']

# %% [markdown]
# # Data Analysis

# %%
data_neg = " ".join(processedtext[:800000])
plt.figure(figsize = (15,15))
wc = WordCloud(max_words=400, width=1000, height=500, max_font_size=100, collocations=False).generate(data_neg)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
data_pos = " ".join(processedtext[800000:])
wc = WordCloud(max_words=400, width=1000, height=500, max_font_size=100, collocations=False).generate(data_pos)
plt.figure(figsize = (15,15))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
df['clean_tweet']= processedtext
def hashtag_extract(tweets):
    hashtags = []
    for tweet in tweets:
        ht = re.findall(r"#(\w+)", tweet)
        hashtags.append(ht)
    return hashtags

# %%
df
# Out:
#          sentiment                                               text  \
# 0                0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1                0  is upset that he can't update his Facebook by ...
# 2                0  @Kenichan I dived many times for the ball. Man...
# 3                0    my whole body feels itchy and like its on fire
# 4                0  @nationwideclass no, it's not behaving at all....
# ...            ...                                                ...
# 1599995          1  Just woke up. Having no school is the best fee...
# 1599996          1  TheWDB.com - Very cool to hear old Walt interv...
# 1599997          1  Are you ready for your MoJo Makeover? Ask me f...
# 1599998          1  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999          1  happy #charitytuesday @theNSPCC @SparksCharity...
#
#                                                clean_tweet
# 0            awww bummer shoulda got david carr third day
# 1        upset update facebook texting might cry result...
# 2        dived many time ball managed save 50 rest go b...
# 3                         whole body feel itchy like fire
# 4                                        behaving mad see
# ...                                                    ...
# 1599995                     woke school best feeling ever
# 1599996           thewdb com cool hear old walt interview
# 1599997                    ready mojo makeover ask detail
# 1599998  happy 38th birthday boo alll time tupac amaru ...
# 1599999                             happy #charitytuesday
#
# [1600000 rows x 3 columns]

# %%
ht_positive = hashtag_extract(df['clean_tweet'][df['sentiment']==1])

ht_negative = hashtag_extract(df['clean_tweet'][df['sentiment']==0])

# %%
ht_positive = sum(ht_positive, [])
ht_negative = sum(ht_negative, [])

# %%
freq = nltk.FreqDist(ht_positive)
d = pd.DataFrame({'Hashtag': list(freq.keys()),'Count': list(freq.values())})
d.head()
# Out:
#       Hashtag  Count
# 0    devunity      1
# 1       alexa      1
# 2       japan      5
# 3       skype      3
# 4  expletives      1

# %%
d = d.nlargest(columns='Count', n=15)
plt.figure(figsize=(15,9))
sns.barplot(data=d, x='Hashtag', y='Count')
plt.show()

# %%
freq = nltk.FreqDist(ht_negative)
d = pd.DataFrame({'Hashtag': list(freq.keys()),
                 'Count': list(freq.values())})
d.head()
# Out:
#        Hashtag  Count
# 0          itm      2
# 1  therapyfail      1
# 2           fb   1059
# 3         ttsc      1
# 4           24     11

# %%
d = d.nlargest(columns='Count', n=15)
plt.figure(figsize=(15,9))
sns.barplot(data=d, x='Hashtag', y='Count')
plt.show()

# %%
#from sklearn.feature_extraction.text import CountVectorizer
#bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
#bow = bow_vectorizer.fit_transform(df['clean_tweet'])

# %%
#from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(bow, df['sentiment'], random_state=42, test_size=0.25)

# %%
#from sklearn.linear_model import LogisticRegression
#from sklearn.metrics import f1_score, accuracy_score
#model = LogisticRegression()
#model.fit(x_train, y_train)
#pred = model.predict(x_test)
#f1_score(y_test, pred)

# %%
#accuracy_score(y_test,pred)

# %% [markdown]
# # Split data as train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(processedtext, sentiment, test_size = 0.20, random_state = 1)

# %% [markdown]
# # Text feature extraction using TF*IDF

# %%
vectoriser = TfidfVectorizer(ngram_range=(1,2), max_features=500000)
vectoriser.fit(X_train)
# Out:
# TfidfVectorizer(max_features=500000, ngram_range=(1, 2))

# %%
X_train = vectoriser.transform(X_train)
X_test  = vectoriser.transform(X_test)

# %%
def model_Evaluate(model):
    
    y_pred = model.predict(X_test)

    print(classification_report(y_test, y_pred))
    
    cf_matrix = confusion_matrix(y_test, y_pred)

    categories  = ['Negative','Positive']
    group_names = ['True Neg','False Pos', 'False Neg','True Pos']
    group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten() / np.sum(cf_matrix)]

    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)

    sns.heatmap(cf_matrix, annot = labels, cmap = 'Blues',fmt = '',
                xticklabels = categories, yticklabels = categories)

    plt.xlabel("Predicted values", fontdict = {'size':10}, labelpad = 10)
    plt.ylabel("Actual values"   , fontdict = {'size':10}, labelpad = 10)
    plt.title ("Confusion Matrix", fontdict = {'size':15}, pad = 20)

# %%
BNBmodel = BernoulliNB(alpha = 2)
BNBmodel.fit(X_train, y_train)
acc_BNB= model_Evaluate(BNBmodel)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77    160156
#            1       0.76      0.81      0.79    159844
#
#     accuracy                           0.78    320000
#    macro avg       0.78      0.78      0.78    320000
# weighted avg       0.78      0.78      0.78    320000

# %%
file = open('vectoriser-ngram-(1,2).pickle','wb')
pickle.dump(vectoriser, file)
file.close()
file = open('Sentiment-BNB.pickle','wb')
pickle.dump(BNBmodel, file)
file.close()

# %%
def load_models():
    
    file = open('vectoriser-ngram-(1,2).pickle', 'rb')
    vectoriser = pickle.load(file)
    file.close()

    file = open('Sentiment-BNBv1.pickle', 'rb')
    BNBmodel = pickle.load(file)
    file.close()
    
    return vectoriser, BNBmodel

def predict(vectoriser, model, text):

    textdata = vectoriser.transform(clean_dataset(text))
    sentiment = model.predict(textdata)
    

    data = []
    for text, pred in zip(text, sentiment):
        data.append((text,pred))
        
  
    df = pd.DataFrame(data, columns = ['text','sentiment'])
    df = df.replace([0,1], ["Negative","Positive"])
    return df

if __name__=="__main__":
  
    text = ["Ankara University sent three messages in one day, legal persons are more loyal than real persons",
            "I'm living my life alone, I'm going to Adana, to drink milkshake from the buffet.",
            "I think you are a depressive person",
           "I loved you despite you"]
    
    df = predict(vectoriser, BNBmodel, text)
    print(df.head())
# Out:
#                                                 text sentiment
# 0  Ankara University sent three messages in one d...  Positive
# 1  I'm living my life alone, I'm going to Adana, ...  Negative
# 2                I think you are a depressive person  Negative
# 3                            I loved you despite you  Positive
